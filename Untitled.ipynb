# %%
a=7

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\elcot\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
x=4
x="sally"
x=8
print(x)
# Out:
# 8

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=4
A="sally"
print(a)
print(A)
# Out:
# 4
# sally

# %%
x,y,z="apple","banana","mango"
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# mango

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
fruits=["apple","banana","mango"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# mango

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x=5
print(type(x))
print(x)
# Out:
# <class 'int'>
# 5

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=356522554887711
z=-325522
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=3+5j
y=5j
z=-5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
print("""python is a,programming language""")
# Out:
# python is a,programming language

# %%
a="Hello,World!"
print(a[1])
# Out:
# e

# %%
for x in "sky":
    print(x)
# Out:
# s
# k
# y

# %%
a="Hello,World!"
print(len(a))
# Out:
# 12

# %%
txt="The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt="The best things in life are free!"
if"free"in txt:
    print("yes,'free is present")
# Out:
# yes,'free is present

# %%
txt="The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
b="Hello,World!"
print(b[2:5])
# Out:
# llo

# %%
a=b="Hello,World!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower())
# Out:
# Hello
# llo,World!
# orl
# HELLO,WORLD!
# hello,world!

# %%
a=" Hello, World!"
print(len(a))
print(a.strip())
print(a.replace("H","J"))
print(a.split(","))
# Out:
# 14
# Hello, World!
#  Jello, World!
# [' Hello', ' World!']

# %%
a="Hello"
b="World"
c=a + b
print(c)
# Out:
# HelloWorld

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry","apple","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["abc",34,True,40,"male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=list(("apple","banana","cherry","orange","kiwi","melon","mango"))
print(thislist[1])
print(thislist[-1])
print(thislist[2:5])
print(thislist[:4])
print(thislist[-4:-1])
# Out:
# banana
# mango
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['orange', 'kiwi', 'melon']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(1,"orange")
print(thislist)
thislist.remove("banana")
print(thislist)
for x in thislist:
  print(x)
  for i in range(len(thislist)):
    print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'cherry', 'orange']
# apple
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange
# cherry
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange

# %%
mytuple=("apple","banana","cherry")
thistuple=("apple","banana","cherry")
print(thistuple)
print(thistuple[-1])
print(thistuple[1])
# Out:
# ('apple', 'banana', 'cherry')
# cherry
# banana

# %%
thistuple=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
myset={"apple","banana","cherry"}
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
charge=int(input("Enter your battery level:"))
if charge>=90 :
    print("your battery is full")
elif charge>=50 :
    print("need to charge your mobile")
else:
    print("Battery low")
# Out:
# Enter your battery level: 90
# your battery is full

# %%
signal=input("Enter the traffic signals:")
if signal=="red" :
    print("STOP")
elif signal=="yellow" :
    print("READY")
elif signal=="green" :
    print("GO")
# Out:
# Enter the traffic signals: blue

# %%
myset={"apple","banana","cherry"}
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
thisset={1,"apple","banana","cherry",True,0,2}
print(thisset)
thisset=("apple","banana","cherry")
print(thisset)
# Out:
# {0, 1, 2, 'cherry', 'apple', 'banana'}
# ('apple', 'banana', 'cherry')

# %%
set1={"apple","banana","cherry"}
set2={1,5,7,9,3}
set3={True,False,False}
print(set1)
print(set2)
print(set3)
# Out:
# {'banana', 'cherry', 'apple'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
  print(x)
# Out:
# banana
# cherry
# apple

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 'b', 'c', 3, 'a'}

# %%
txt="hello"
count=int(input("Enter count"))
for i in range(6):
    print(txt)
# Out:
# Enter count 90
# hello
# hello
# hello
# hello
# hello

# %%
num=5
for i in range():
    for j in
